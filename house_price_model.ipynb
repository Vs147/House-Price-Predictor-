# %%
import numpy as np
import pandas as pd

# %%
data= pd.read_csv(r"C:\Users\HP\Downloads\benguluru house prediction\Bengaluru_House_Data.csv")
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
data.shape
# Out:
# (13320, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
for column in data.columns:
    x = data[column].value_counts()
    print(column)
    print(x)
    print( )
# Out:
# area_type
# area_type
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: count, dtype: int64
#
# availability
# availability
# Ready To Move    10581
# 18-Dec             307
# 18-May             295
# 18-Apr             271
# 18-Aug             200
#                  ...
# 15-Aug               1
# 17-Jan               1
# 16-Nov               1
# 16-Jan               1
# 14-Jul               1
# Name: count, Length: 81, dtype: int64
#
# location
# location
# Whitefield                        540
# Sarjapur  Road                    399
# Electronic City                   302
# Kanakpura Road                    273
# Thanisandra                       234
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# Abshot Layout                       1
# ...

# %%
data.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
data.drop(columns = ['area_type', 'availability', 'society','balcony',],inplace = True)

# %%
data
# Out:
#                        location       size total_sqft  bath   price
# 0      Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2                   Uttarahalli      3 BHK       1440   2.0   62.00
# 3            Lingadheeranahalli      3 BHK       1521   3.0   95.00
# 4                      Kothanur      2 BHK       1200   2.0   51.00
# ...                         ...        ...        ...   ...     ...
# 13315                Whitefield  5 Bedroom       3453   4.0  231.00
# 13316             Richards Town      4 BHK       3600   5.0  400.00
# 13317     Raja Rajeshwari Nagar      2 BHK       1141   2.0   60.00
# 13318           Padmanabhanagar      4 BHK       4689   4.0  488.00
# 13319              Doddathoguru      1 BHK        550   1.0   17.00
#
# [13320 rows x 5 columns]

# %%
data.describe()
# Out:
#                bath         price
# count  13247.000000  13320.000000
# mean       2.692610    112.565627
# std        1.341458    148.971674
# min        1.000000      8.000000
# 25%        2.000000     50.000000
# 50%        2.000000     72.000000
# 75%        3.000000    120.000000
# max       40.000000   3600.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    13319 non-null  object
#  1   size        13304 non-null  object
#  2   total_sqft  13320 non-null  object
#  3   bath        13247 non-null  float64
#  4   price       13320 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 520.4+ KB

# %%
data.isnull().sum()
# Out:
# location       1
# size          16
# total_sqft     0
# bath          73
# price          0
# dtype: int64

# %%
# data.value_counts()
data['location'].value_counts()
# Out:
# location
# Whitefield                        540
# Sarjapur  Road                    399
# Electronic City                   302
# Kanakpura Road                    273
# Thanisandra                       234
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# Abshot Layout                       1
# Name: count, Length: 1305, dtype: int64

# %%
data['location'] = data['location'].fillna('Sarjapur  Road')

# %%
data['size'].value_counts()
# Out:
# size
# 2 BHK         5199
# 3 BHK         4310
# 4 Bedroom      826
# 4 BHK          591
# 3 Bedroom      547
# 1 BHK          538
# 2 Bedroom      329
# 5 Bedroom      297
# 6 Bedroom      191
# 1 Bedroom      105
# 8 Bedroom       84
# 7 Bedroom       83
# 5 BHK           59
# 9 Bedroom       46
# 6 BHK           30
# 7 BHK           17
# 1 RK            13
# 10 Bedroom      12
# 9 BHK            8
# 8 BHK            5
# 11 BHK           2
# 11 Bedroom       2
# 10 BHK           2
# 14 BHK           1
# 13 BHK           1
# 12 Bedroom       1
# 27 BHK           1
# 43 Bedroom       1
# 16 BHK           1
# 19 BHK           1
# 18 Bedroom       1
# Name: count, dtype: int64

# %%
data['size']=data['size'].fillna('2 BHK')

# %%
data['bath']=data['bath'].fillna(data['bath'].median())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    13320 non-null  object
#  1   size        13320 non-null  object
#  2   total_sqft  13320 non-null  object
#  3   bath        13320 non-null  float64
#  4   price       13320 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 520.4+ KB

# %%
data.isnull().sum()
# Out:
# location      0
# size          0
# total_sqft    0
# bath          0
# price         0
# dtype: int64

# %%
data['bhk'] = data['size'].str.split().str.get(0).astype(int)

# %%
data
# Out:
#                        location       size total_sqft  bath   price  bhk
# 0      Electronic City Phase II      2 BHK       1056   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0  120.00    4
# 2                   Uttarahalli      3 BHK       1440   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK       1521   3.0   95.00    3
# 4                      Kothanur      2 BHK       1200   2.0   51.00    2
# ...                         ...        ...        ...   ...     ...  ...
# 13315                Whitefield  5 Bedroom       3453   4.0  231.00    5
# 13316             Richards Town      4 BHK       3600   5.0  400.00    4
# 13317     Raja Rajeshwari Nagar      2 BHK       1141   2.0   60.00    2
# 13318           Padmanabhanagar      4 BHK       4689   4.0  488.00    4
# 13319              Doddathoguru      1 BHK        550   1.0   17.00    1
#
# [13320 rows x 6 columns]

# %%
data['size_name'] = data['size'].str.split().str.get(1)

# %%
data
# Out:
#                        location       size total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK       1056   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0  120.00    4
# 2                   Uttarahalli      3 BHK       1440   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK       1521   3.0   95.00    3
# 4                      Kothanur      2 BHK       1200   2.0   51.00    2
# ...                         ...        ...        ...   ...     ...  ...
# 13315                Whitefield  5 Bedroom       3453   4.0  231.00    5
# 13316             Richards Town      4 BHK       3600   5.0  400.00    4
# 13317     Raja Rajeshwari Nagar      2 BHK       1141   2.0   60.00    2
# 13318           Padmanabhanagar      4 BHK       4689   4.0  488.00    4
# 13319              Doddathoguru      1 BHK        550   1.0   17.00    1
#
#       size_name
# 0           BHK
# 1       Bedroom
# 2           BHK
# 3           BHK
# ...

# %%
data['total_sqft'].head(60)
# Out:
# 0            1056
# 1            2600
# 2            1440
# 3            1521
# 4            1200
# 5            1170
# 6            2732
# 7            3300
# 8            1310
# 9            1020
# 10           1800
# 11           2785
# 12           1000
# 13           1100
# 14           2250
# 15           1175
# 16           1180
# 17           1540
# 18           2770
# 19           1100
# 20            600
# 21           1755
# 22           2800
# 23           1767
# 24            510
# 25           1250
# 26            660
# 27           1610
# 28           1151
# 29           1025
# 30    2100 - 2850
# 31           1075
# 32           1760
# 33           1693
# 34           1925
# 35            700
# 36           1070
# 37           1724
# 38           1290
# 39           1143
# 40           1296
# 41           1254
# 42            600
# 43            660
# 44        1330.74
# 45            600
# 46            970
# 47           1459
# 48            800
# 49            869
# ...

# %%
def trange(x):
    r = x.split('-')
    if len(r)==2:
        return (float(r[0])+float(r[1]))/2
    try:
        return float(x)
    except:
        return None

# %%
data['total_sqft']=data['total_sqft'].apply(trange)

# %%
data.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
#
#   size_name
# 0       BHK
# 1   Bedroom
# 2       BHK
# 3       BHK
# 4       BHK

# %%
data['total_sqft'].head(60)
# Out:
# 0     1056.00
# 1     2600.00
# 2     1440.00
# 3     1521.00
# 4     1200.00
# 5     1170.00
# 6     2732.00
# 7     3300.00
# 8     1310.00
# 9     1020.00
# 10    1800.00
# 11    2785.00
# 12    1000.00
# 13    1100.00
# 14    2250.00
# 15    1175.00
# 16    1180.00
# 17    1540.00
# 18    2770.00
# 19    1100.00
# 20     600.00
# 21    1755.00
# 22    2800.00
# 23    1767.00
# 24     510.00
# 25    1250.00
# 26     660.00
# 27    1610.00
# 28    1151.00
# 29    1025.00
# 30    2475.00
# 31    1075.00
# 32    1760.00
# 33    1693.00
# 34    1925.00
# 35     700.00
# 36    1070.00
# 37    1724.00
# 38    1290.00
# 39    1143.00
# 40    1296.00
# 41    1254.00
# 42     600.00
# 43     660.00
# 44    1330.74
# 45     600.00
# 46     970.00
# 47    1459.00
# 48     800.00
# 49     869.00
# 50    1270.00
# 51    1670.00
# 52    2010.00
# 53    1185.00
# 54    1600.00
# 55    1200.00
# 56    3210.00
# 57    1500.00
# 58    1407.00
# 59     840.00
# Name: total_sqft, dtype: float64

# %%
data["price_per_sqft"] = (data['price']*100000) /data['total_sqft']

# %%
data.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
#
#   size_name  price_per_sqft
# 0       BHK     3699.810606
# 1   Bedroom     4615.384615
# 2       BHK     4305.555556
# 3       BHK     6245.890861
# 4       BHK     4250.000000

# %%
data.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  13274.000000  13320.000000  13320.000000  13320.000000    1.327400e+04
# mean    1559.626694      2.688814    112.565627      2.802778    7.907501e+03
# std     1238.405258      1.338754    148.971674      1.294496    1.064296e+05
# min        1.000000      1.000000      8.000000      1.000000    2.678298e+02
# 25%     1100.000000      2.000000     50.000000      2.000000    4.266865e+03
# 50%     1276.000000      2.000000     72.000000      3.000000    5.434306e+03
# 75%     1680.000000      3.000000    120.000000      3.000000    7.311746e+03
# max    52272.000000     40.000000   3600.000000     43.000000    1.200000e+07

# %%
data['location'].value_counts()
# Out:
# location
# Whitefield                        540
# Sarjapur  Road                    400
# Electronic City                   302
# Kanakpura Road                    273
# Thanisandra                       234
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# Abshot Layout                       1
# Name: count, Length: 1305, dtype: int64

# %%
data['location'] = data['location'].apply(lambda x:x.strip())

# %%
location_counts = data['location'].value_counts()
location_counts
# Out:
# location
# Whitefield                        541
# Sarjapur  Road                    400
# Electronic City                   304
# Kanakpura Road                    273
# Thanisandra                       237
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# Abshot Layout                       1
# Name: count, Length: 1294, dtype: int64

# %%
location_counts_less_10 = location_counts[location_counts<=10]
location_counts_less_10
# Out:
# location
# Dairy Circle                      10
# Nagappa Reddy Layout              10
# Basapura                          10
# 1st Block Koramangala             10
# Sector 1 HSR Layout               10
#                                   ..
# Bapuji Layout                      1
# 1st Stage Radha Krishna Layout     1
# BEML Layout 5th stage              1
# singapura paradise                 1
# Abshot Layout                      1
# Name: count, Length: 1053, dtype: int64

# %%
data['location'] = data['location'].apply(lambda x :'others' if x in location_counts_less_10 else x )

# %%
data['location'].value_counts()
# Out:
# location
# others                2885
# Whitefield             541
# Sarjapur  Road         400
# Electronic City        304
# Kanakpura Road         273
#                       ...
# Nehru Nagar             11
# Banjara Layout          11
# LB Shastri Nagar        11
# Pattandur Agrahara      11
# Narayanapura            11
# Name: count, Length: 242, dtype: int64

# %%
# outlier detector and removal

data.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  13274.000000  13320.000000  13320.000000  13320.000000    1.327400e+04
# mean    1559.626694      2.688814    112.565627      2.802778    7.907501e+03
# std     1238.405258      1.338754    148.971674      1.294496    1.064296e+05
# min        1.000000      1.000000      8.000000      1.000000    2.678298e+02
# 25%     1100.000000      2.000000     50.000000      2.000000    4.266865e+03
# 50%     1276.000000      2.000000     72.000000      3.000000    5.434306e+03
# 75%     1680.000000      3.000000    120.000000      3.000000    7.311746e+03
# max    52272.000000     40.000000   3600.000000     43.000000    1.200000e+07

# %%
data
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13315                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13316                    others      4 BHK      3600.0   5.0  400.00    4
# 13317     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13318           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13319              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#       size_name  price_per_sqft
# 0           BHK     3699.810606
# ...

# %%
(data['total_sqft']/data['bhk']).describe()  # outlier
# Out:
# count    13274.000000
# mean       575.074878
# std        388.205175
# min          0.250000
# 25%        473.333333
# 50%        552.500000
# 75%        625.000000
# max      26136.000000
# dtype: float64

# %%
data = data[((data['total_sqft']/data['bhk'])>=300)]
data.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  12530.000000  12530.000000  12530.000000  12530.000000    12530.000000
# mean    1594.564544      2.559537    111.382401      2.650838     6303.979357
# std     1261.271296      1.077938    152.077329      0.976678     4162.237981
# min      300.000000      1.000000      8.440000      1.000000      267.829813
# 25%     1116.000000      2.000000     49.000000      2.000000     4210.526316
# 50%     1300.000000      2.000000     70.000000      3.000000     5294.117647
# 75%     1700.000000      3.000000    115.000000      3.000000     6916.666667
# max    52272.000000     16.000000   3600.000000     16.000000   176470.588235

# %%
data.price_per_sqft.describe()
# Out:
# count     12530.000000
# mean       6303.979357
# std        4162.237981
# min         267.829813
# 25%        4210.526316
# 50%        5294.117647
# 75%        6916.666667
# max      176470.588235
# Name: price_per_sqft, dtype: float64

# %%
data.head(50)
# Out:
#                     location       size  total_sqft  bath   price  bhk  \
# 0   Electronic City Phase II      2 BHK     1056.00   2.0   39.07    2
# 1           Chikka Tirupathi  4 Bedroom     2600.00   5.0  120.00    4
# 2                Uttarahalli      3 BHK     1440.00   2.0   62.00    3
# 3         Lingadheeranahalli      3 BHK     1521.00   3.0   95.00    3
# 4                   Kothanur      2 BHK     1200.00   2.0   51.00    2
# 5                 Whitefield      2 BHK     1170.00   2.0   38.00    2
# 6           Old Airport Road      4 BHK     2732.00   4.0  204.00    4
# 7               Rajaji Nagar      4 BHK     3300.00   4.0  600.00    4
# 8               Marathahalli      3 BHK     1310.00   3.0   63.25    3
# 10                Whitefield      3 BHK     1800.00   2.0   70.00    3
# 11                Whitefield  4 Bedroom     2785.00   5.0  295.00    4
# 12        7th Phase JP Nagar      2 BHK     1000.00   2.0   38.00    2
# ...

# %%
# # data.groupby('location')
# for key,df_value in data.groupby('location'):
#         print(key,df_value)

# %%
def handle_outliers_sqft(df):
    df_output = pd.DataFrame()
#     print(df_output)
    for key,df_value in data.groupby('location'):
        m = np.mean(df_value.price_per_sqft)
        st = np.std(df_value.price_per_sqft)
        
        new_df= df_value[(df_value.price_per_sqft>(m-st))&(df_value.price_per_sqft<=(m+st))]
        
        df_output = pd.concat([df_output,new_df],ignore_index = True)
        
    return df_output

        
data = handle_outliers_sqft(data)
data.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  10301.000000  10301.000000  10301.000000  10301.000000    10301.000000
# mean    1508.440608      2.471702     91.286372      2.574896     5659.062876
# std      880.694214      0.979449     86.342786      0.897649     2265.774749
# min      300.000000      1.000000     10.000000      1.000000     1250.000000
# 25%     1110.000000      2.000000     49.000000      2.000000     4244.897959
# 50%     1286.000000      2.000000     67.000000      2.000000     5175.600739
# 75%     1650.000000      3.000000    100.000000      3.000000     6428.571429
# max    30400.000000     16.000000   2200.000000     16.000000    24509.803922

# %%
data
# Out:
#                   location       size  total_sqft  bath   price  bhk  \
# 0      1st Block Jayanagar      4 BHK      2850.0   4.0  428.00    4
# 1      1st Block Jayanagar      3 BHK      1630.0   3.0  194.00    3
# 2      1st Block Jayanagar      3 BHK      1875.0   2.0  235.00    3
# 3      1st Block Jayanagar      3 BHK      1200.0   2.0  130.00    3
# 4      1st Block Jayanagar      2 BHK      1235.0   2.0  148.00    2
# ...                    ...        ...         ...   ...     ...  ...
# 10296               others      2 BHK      1353.0   2.0  110.00    2
# 10297               others  1 Bedroom       812.0   1.0   26.00    1
# 10298               others      3 BHK      1440.0   2.0   63.93    3
# 10299               others      2 BHK      1075.0   2.0   48.00    2
# 10300               others      4 BHK      3600.0   5.0  400.00    4
#
#       size_name  price_per_sqft
# 0           BHK    15017.543860
# 1           BHK    11901.840491
# 2           BHK    12533.333333
# ...

# %%
data.price_per_sqft.describe()
# Out:
# count    10301.000000
# mean      5659.062876
# std       2265.774749
# min       1250.000000
# 25%       4244.897959
# 50%       5175.600739
# 75%       6428.571429
# max      24509.803922
# Name: price_per_sqft, dtype: float64

# %%
def bhk_outlier_handle(df):
    convert  = np.array([])  # Initialize an empty NumPy array to store indices of rows to be dropped

    # Grouping the DataFrame by location
    for location, location_df in df.groupby('location'):
        bhk_brief = {}  # Dictionary to store statistics for each BHK (Bedrooms, Hall, Kitchen) configuration

        # Grouping the location DataFrame by the number of bedrooms (bhk)
        for bhk, bhk_df in location_df.groupby('bhk'):
#             print(bhk_df)
#             print(bhk)
            # Calculating mean, standard deviation, and count of prices per square foot for each BHK configuration
            bhk_brief[bhk] = {
                'mean': np.mean(bhk_df.price_per_sqft),
                'std': np.std(bhk_df.price_per_sqft),
                'count': bhk_df.shape[0]
            }
#             print(bhk_brief)
#         Iterating over each BHK configuration again
        for bhk, bhk_df in location_df.groupby('bhk'):
            # Checking if statistics for (bhk-1) exists and the count is greater than 5
            stats = bhk_brief.get(bhk - 1)
#             print(stats)
            if stats and stats['count'] > 5:
                # Finding indices of rows where price per sqft is less than the mean of (bhk-1)
                convert = np.append(convert, bhk_df[bhk_df.price_per_sqft < (stats['mean'])].index.values)
#                 print(bhk_df)

#     Dropping rows with outlier prices
    return df.drop(convert, axis='index')

# %%
#         for bhk, bhk_df in location_df.groupby('bhk'):

# bhk_brief[bhk] = {
#                 'mean': np.mean(bhk_df.price_per_sqft),
#                 'std': np.std(bhk_df.price_per_sqft),
#                 'count': bhk_df.shape[0]
#             }
#             print(bhk_brief)


# for bhk, bhk_df in location_df.groupby('bhk'):
#     stats = bhk_brief.get(bhk - 1)
#     print(stats)
    
data  =  bhk_outlier_handle(data)

# %%
# data.shape
data.price_per_sqft.describe()
# Out:
# count     7360.000000
# mean      6127.742397
# std       2409.144904
# min       1300.000000
# 25%       4600.000000
# 50%       5680.396754
# 75%       6896.551724
# max      24509.803922
# Name: price_per_sqft, dtype: float64

# %%
data
# Out:
#                   location       size  total_sqft  bath  price  bhk size_name  \
# 0      1st Block Jayanagar      4 BHK      2850.0   4.0  428.0    4       BHK
# 1      1st Block Jayanagar      3 BHK      1630.0   3.0  194.0    3       BHK
# 2      1st Block Jayanagar      3 BHK      1875.0   2.0  235.0    3       BHK
# 3      1st Block Jayanagar      3 BHK      1200.0   2.0  130.0    3       BHK
# 4      1st Block Jayanagar      2 BHK      1235.0   2.0  148.0    2       BHK
# ...                    ...        ...         ...   ...    ...  ...       ...
# 10292               others      2 BHK      1200.0   2.0   70.0    2       BHK
# 10293               others      1 BHK      1800.0   1.0  200.0    1       BHK
# 10296               others      2 BHK      1353.0   2.0  110.0    2       BHK
# 10297               others  1 Bedroom       812.0   1.0   26.0    1   Bedroom
# 10300               others      4 BHK      3600.0   5.0  400.0    4       BHK
#
#        price_per_sqft
# ...

# %%
data.drop(columns = ['size','price_per_sqft'],inplace = True)

# %%
# cleaned data
data.head()
# Out:
#               location  total_sqft  bath  price  bhk size_name
# 0  1st Block Jayanagar      2850.0   4.0  428.0    4       BHK
# 1  1st Block Jayanagar      1630.0   3.0  194.0    3       BHK
# 2  1st Block Jayanagar      1875.0   2.0  235.0    3       BHK
# 3  1st Block Jayanagar      1200.0   2.0  130.0    3       BHK
# 4  1st Block Jayanagar      1235.0   2.0  148.0    2       BHK

# %%
data.drop(columns = ['size_name'],inplace = True)

# %%
# data.head(20)
data
# Out:
#                   location  total_sqft  bath  price  bhk
# 0      1st Block Jayanagar      2850.0   4.0  428.0    4
# 1      1st Block Jayanagar      1630.0   3.0  194.0    3
# 2      1st Block Jayanagar      1875.0   2.0  235.0    3
# 3      1st Block Jayanagar      1200.0   2.0  130.0    3
# 4      1st Block Jayanagar      1235.0   2.0  148.0    2
# ...                    ...         ...   ...    ...  ...
# 10292               others      1200.0   2.0   70.0    2
# 10293               others      1800.0   1.0  200.0    1
# 10296               others      1353.0   2.0  110.0    2
# 10297               others       812.0   1.0   26.0    1
# 10300               others      3600.0   5.0  400.0    4
#
# [7360 rows x 5 columns]

# %%
# data.to_csv('cleaned__house_price.csv',index=False)

# %%
# train_test_split
X = data.drop(columns = ['price'])
y = data['price']

# %%
# X.to_csv('cleaned_data_house.csv')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.compose import make_column_transformer

from sklearn.pipeline import make_pipeline

from sklearn.metrics import r2_score

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 0)
print(X_train.shape)
print(X_test.shape)
# Out:
# (5888, 4)
# (1472, 4)

# %%
column_trans = make_column_transformer((OneHotEncoder(sparse = False),['location']),remainder = 'passthrough')

# %%
column_trans
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('onehotencoder', OneHotEncoder(sparse=False),
#                                  ['location'])])

# %%
scaler = StandardScaler()

# %%
lr = LinearRegression()

# %%
pipe = make_pipeline(column_trans,scaler,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['location'])])),
#                 ('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %%
y_pred = pipe.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8296332921006168

# %%
ridge = Ridge()

# %%
pipe = make_pipeline(column_trans,scaler,ridge)

# %%
pipe.fit(X_train,y_train)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['location'])])),
#                 ('standardscaler', StandardScaler()), ('ridge', Ridge())])

# %%
y_pred_ridge = pipe.predict(X_test)

# %%
r2_score(y_test,y_pred_ridge)
# Out:
# 0.8296651410179644

# %%
lasso = Lasso()
pipe =  make_pipeline(column_trans,scaler,lasso)

# %%
pipe.fit(X_train,y_train)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['location'])])),
#                 ('standardscaler', StandardScaler()), ('lasso', Lasso())])

# %%
y_pred_lasso = pipe.predict(X_test)
r2_score(y_test,y_pred_lasso)
# Out:
# 0.8199181874762704

# %%
# import pickle

# %%
# pickle.dump(pipe,open('Ridgemodel.pkl','wb'))
